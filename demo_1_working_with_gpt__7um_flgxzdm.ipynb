# %% [markdown]
# ## Demo-1: Working with GPT

# %% [markdown]
# # Step-1: Install the Transformers Library

# %%
# !pip install transformers

# %% [markdown]
# # Step-2: Import the Pipeline

# %%
from transformers import pipeline, set_seed

# %% [markdown]
# # Step-3: Initialize Text Generation Pipeline and Generate and Display Text

# %%
# Initialize the pipeline for text generation, using GPT-2 as an example
generator = pipeline('text-generation', model='gpt2')

# Optionally set a seed for reproducibility
set_seed(42)

# Generate text based on a prompt
prompt = "Once upon a time in a faraway land,"
generated_text = generator(prompt, max_length=50, num_return_sequences=1)

# Output the generated text
print(generated_text[0]['generated_text'])
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Once upon a time in a faraway land, someone heard that some people were dancing with a human spirit. They told each other that they had seen an evil spirit. Many were afraid but so was the spirits themselves. A few others turned this idea
